# %% [markdown]
# # 見出し
#
# 1. テキスト
#
# - 箇条書き
#  - インデント
#   - あ
#   - fe
# - か
#
# `テキスト`
#
# [リンク](https://www.google.co.jp/)
#
# **太字**
#
# \エスケープ
#
# ***
# ---
#
# ```python
#
# if a > 0:
#     print('Hello')
#
# ```
#
# | 1 | 2 |
# |:-:|:-:|
# | 1 | 2 |
# | 1 | 2 |
#
#
# <font color="Red">テキスト</font>
#
# </ br>

# %% [markdown]
# jupyterテーマメモ
# 　jt -t onedork -vim -N -T -tfs 9 -lineh 170 -ofs 10
#
#  　(ofs：出力セルフォント）
